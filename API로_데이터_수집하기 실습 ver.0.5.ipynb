# %% [markdown]
# <a href="https://colab.research.google.com/github/neddy0318/neddy_space/blob/main/API%EB%A1%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%88%98%EC%A7%91%ED%95%98%EA%B8%B0%20%EC%8B%A4%EC%8A%B5%20ver.0.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = "http://www.naver.com"
requests.get(url)

#200이면 정상 응답 하는것
#404 등 4(클라이언트 오류)나 5(서버오류)으로 시작하면 X
# Out:
# <Response [200]>

# %%
requests.__version__
# Out:
# '2.31.0'

# %%
import requests

url = 'http://openapi.seoul.go.kr:8088/sample/xml/tbLnOpendataRentV/1/5/'

requests.get(url).text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<tbLnOpendataRentV>\n<list_total_count>5791017</list_total_count>\n<RESULT>\n<CODE>INFO-000</CODE>\n<MESSAGE>정상 처리되었습니다</MESSAGE>\n</RESULT>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11230</SGG_CD>\n<SGG_NM>동대문구</SGG_NM>\n<BJDONG_CD>10700</BJDONG_CD>\n<BJDONG_NM>청량리동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0235</BOBN>\n<BUBN>0006</BUBN>\n<FLR_NO>16</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>20.92</RENT_AREA>\n<RENT_GTN>1000</RENT_GTN>\n<RENT_FEE>100</RENT_FEE>\n<BLDG_NM>힐스테이트 청량리역</BLDG_NM>\n<BUILD_YEAR>2023</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.03~25.03</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11560</SGG_CD>\n<SGG_NM>영등포구</SGG_NM>\n<BJDONG_CD>10900</BJDONG_CD>\n<BJDONG_NM>영등포동8가</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0065</BOBN>\n<BUBN>0001</BUBN>\n<FLR_NO>6</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>17.58</RENT_AREA>\n<RENT_GTN>22000</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>엠캐슬150</BLDG_NM>\n<BUILD_YEAR>2024</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11545</SGG_CD>\n<SGG_NM>금천구</SGG_NM>\n<BJDONG_CD>10200</BJDONG_CD>\n<BJDONG_NM>독산동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0144</BOBN>\n<BUBN>0019</BUBN>\n<FLR_NO>9</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>21.37</RENT_AREA>\n<RENT_GTN>23600</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>킹캐슬8차</BLDG_NM>\n<BUILD_YEAR>2024</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11470</SGG_CD>\n<SGG_NM>양천구</SGG_NM>\n<BJDONG_CD>10100</BJDONG_CD>\n<BJDONG_NM>신정동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>1182</BOBN>\n<BUBN>0015</BUBN>\n<FLR_NO>5</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>23.31</RENT_AREA>\n<RENT_GTN>21200</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>보스코 빌딩</BLDG_NM>\n<BUILD_YEAR>2020</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11230</SGG_CD>\n<SGG_NM>동대문구</SGG_NM>\n<BJDONG_CD>10400</BJDONG_CD>\n<BJDONG_NM>전농동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0620</BOBN>\n<BUBN>0071</BUBN>\n<FLR_NO>10</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>43.44</RENT_AREA>\n<RENT_GTN>3000</RENT_GTN>\n<RENT_FEE>150</RENT_FEE>\n<BLDG_NM>청량리더블유디세븐스</BLDG_NM>\n<BUILD_YEAR>2023</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~25.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n</tbLnOpendataRentV>\n'

# %%
#강의 때 배운 파라미터 방식으로 안 됨. url에 년도 입력하니 해결

import requests

url = 'http://openapi.seoul.go.kr:8088/4178724f416e656437366d46676961/xml/tbLnOpendataRentV/1/100/2024'

# 파라미터를 딕셔너리 형태로 입력
params = {
    'KEY': '4178724f416e656437366d46676961',
    'TYPE': 'xml',
    'SERVICE': 'tbLnOpendataRentV',
    'START_INDEX': 0,
    'END_INDEX': 100,
    'ACC_YEAR': '2024',   # 접수연도
}

response = requests.get(url, params)
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<tbLnOpendataRentV>\n<list_total_count>117777</list_total_count>\n<RESULT>\n<CODE>INFO-000</CODE>\n<MESSAGE>정상 처리되었습니다</MESSAGE>\n</RESULT>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11650</SGG_CD>\n<SGG_NM>서초구</SGG_NM>\n<BJDONG_CD>10800</BJDONG_CD>\n<BJDONG_NM>서초동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>1337</BOBN>\n<BUBN>0006</BUBN>\n<FLR_NO>9</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>26.27</RENT_AREA>\n<RENT_GTN>23400</RENT_GTN>\n<RENT_FEE>10</RENT_FEE>\n<BLDG_NM>강남 효성 해링턴 타워</BLDG_NM>\n<BUILD_YEAR>2013</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>갱신</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT>250000000</BEFORE_GRNTY_AMOUNT>\n<BEFORE_MT_RENT_CHRGE>0</BEFORE_MT_RENT_CHRGE>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11500</SGG_CD>\n<SGG_NM>강서구</SGG_NM>\n<BJDONG_CD>10500</BJDONG_CD>\n<BJDONG_NM>마곡동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0773</BOBN>\n<BUBN>0003</BUBN>\n<FLR_NO>8</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>24.57</RENT_AREA>\n<RENT_GTN>16847</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>힐스테이트에코동익</BLDG_NM>\n<BUILD_YEAR>2017</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~25.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11560</SGG_CD>\n<SGG_NM>영등포구</SGG_NM>\n<BJDONG_CD>11800</BJDONG_CD>\n<BJDONG_NM>도림동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0265</BOBN>\n<BUBN>0008</BUBN>\n<FLR_NO>2</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>30.87</RENT_AREA>\n<RENT_GTN>9000</RENT_GTN>\n<RENT_FEE>50</RENT_FEE>\n<BLDG_NM>도림동 하나 아파텔(2차)</BLDG_NM>\n<BUILD_YEAR>2003</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.05~26.05</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11230</SGG_CD>\n<SGG_NM>동대문구</SGG_NM>\n<BJDONG_CD>10700</BJDONG_CD>\n<BJDONG_NM>청량리동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0235</BOBN>\n<BUBN>0006</BUBN>\n<FLR_NO>16</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>20.92</RENT_AREA>\n<RENT_GTN>1000</RENT_GTN>\n<RENT_FEE>100</RENT_FEE>\n<BLDG_NM>힐스테이트 청량리역</BLDG_NM>\n<BUILD_YEAR>2023</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.03~25.03</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11530</SGG_CD>\n<SGG_NM>구로구</SGG_NM>\n<BJDONG_CD>10300</BJDONG_CD>\n<BJDONG_NM>가리봉동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0135</BOBN>\n<BUBN>0051</BUBN>\n<FLR_NO>5</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>42.89</RENT_AREA>\n<RENT_GTN>26600</RENT_GTN>\n<RENT_FEE>10</RENT_FEE>\n<BLDG_NM>(135-51)</BLDG_NM>\n<BUILD_YEAR>2023</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11545</SGG_CD>\n<SGG_NM>금천구</SGG_NM>\n<BJDONG_CD>10200</BJDONG_CD>\n<BJDONG_NM>독산동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0144</BOBN>\n<BUBN>0019</BUBN>\n<FLR_NO>9</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>21.37</RENT_AREA>\n<RENT_GTN>23600</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>킹캐슬8차</BLDG_NM>\n<BUILD_YEAR>2024</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SE ...

# %%
#강의 때 들은 입력방식으로는 출력 에러남

import requests
url = 'http://openapi.seoul.go.kr:8088/sample/xml/tbLnOpendataRentV/1/5/'

#파라미터를 딕셔너리 형태로 입력
params = {
    ('KEY', '4178724f416e656437366d46676961'),
    ('TYPE', 'json'),
    ('SERVICE' 'tbLnOpendataRentV'),
    ('START_INDEX',0),
    ('END_INDEX', 20),
    ('CNTRCT_DE', '20240202'),   #계약일
    ('SGG_NM', '광진구')}   #자치구명
requests.get(url, params).text
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9d47b879fc96> in <cell line: 13>()
#      11     ('CNTRCT_DE', '20240202'),   #계약일
#      12     ('SGG_NM', '광진구')}   #자치구명
# ---> 13 requests.get(url, params).text
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     573             hooks=hooks,
#     574         )
# --> 575         prep = self.prepare_request(req)
#     576
#     577         proxies = proxies or {}
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in prepare_request(self, request)
#     484
#     485         p = PreparedRequest()
# --> 486         p.prepare(
#     487             method=request.method.upper(),
#     488             url=request.url,
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     366
#     367         self.prepare_method(method)
# --> 368         self.prepare_url(url, params)
#     369         self.prepare_headers(headers)
#     370         self.prepare_cookies(cookies)
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in prepare_url(self, url, params)
#     472             params = to_native_string(params)
#     473
# --> 474         enc_params = self._encode_params(params)
#     475         if enc_params:
#     476             if query:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in _encode_params(data)
#     119         elif hasattr(data, "__iter__"):
#     120             result = []
# --> 121             for k, vs in to_key_val_list(data):
#     122                 if isinstance(vs, basestring) or not hasattr(vs, "__iter__"):
#     123                     vs = [vs]
#
# ValueError: too many values to unpack (expected 2)

# %%
#파라미터 값과 상관 없이 샘플 데이터만 나옴

import requests
import xml.etree.ElementTree as ET    #ET : xml 전처리해주는 도구
import pandas as pd

import requests

url = 'http://openapi.seoul.go.kr:8088/4178724f416e656437366d46676961/xml/tbLnOpendataRentV/1/5/'

# 파라미터를 딕셔너리 형태로 입력
params = {
    'KEY': '4178724f416e656437366d46676961',
    'TYPE': 'xml',
    'SERVICE': 'tbLnOpendataRentV',
    'START_INDEX': 0,
    'END_INDEX': 20,
    'CNTRCT_DE': '20240202',   # 계약일
    'SGG_NM': '광진구'   # 자치구명
}

response = requests.get(url, params=params)
#dir(reponse)를 통해 내부 지원하는 메소드를 확인할 수 있음
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <tbLnOpendataRentV>
# <list_total_count>5791017</list_total_count>
# <RESULT>
# <CODE>INFO-000</CODE>
# <MESSAGE>정상 처리되었습니다</MESSAGE>
# </RESULT>
# <row>
# <ACC_YEAR>2024</ACC_YEAR>
# <SGG_CD>11230</SGG_CD>
# <SGG_NM>동대문구</SGG_NM>
# <BJDONG_CD>10700</BJDONG_CD>
# <BJDONG_NM>청량리동</BJDONG_NM>
# <LAND_GBN>1</LAND_GBN>
# <LAND_GBN_NM>대지</LAND_GBN_NM>
# <BOBN>0235</BOBN>
# <BUBN>0006</BUBN>
# <FLR_NO>16</FLR_NO>
# <CNTRCT_DE>20240325</CNTRCT_DE>
# <RENT_GBN>월세</RENT_GBN>
# <RENT_AREA>20.92</RENT_AREA>
# <RENT_GTN>1000</RENT_GTN>
# <RENT_FEE>100</RENT_FEE>
# <BLDG_NM>힐스테이트 청량리역</BLDG_NM>
# <BUILD_YEAR>2023</BUILD_YEAR>
# <HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>
# <CNTRCT_PRD>24.03~25.03</CNTRCT_PRD>
# <NEW_RON_SECD>신규</NEW_RON_SECD>
# <CNTRCT_UPDT_RQEST_AT/>
# <BEFORE_GRNTY_AMOUNT/>
# <BEFORE_MT_RENT_CHRGE/>
# </row>
# <row>
# <ACC_YEAR>2024</ACC_YEAR>
# <SGG_CD>11560</SGG_CD>
# <SGG_NM>영등포구</SGG_NM>
# <BJDONG_CD>10900</BJDONG_CD>
# <BJDONG_NM>영등포동8가</BJDONG_NM>
# <LAND_GBN>1</LAND_GBN>
# <LAND_GBN_NM>대지</LAND_GBN_NM>
# <BOBN>0065</BOBN>
# <BUBN>0001</BUBN>
# <FLR_NO>6</FLR_NO>
# <CNTRCT_DE>20240325</CNTRCT_DE>
# <RENT_GBN>전세</RENT_GBN>
# <RENT_AREA>17.58</RENT_AREA>
# <RENT_GTN>22000</RENT_GTN>
# <RENT_FEE>0</RENT_FEE>
# <BLDG_NM>엠캐슬150</BLDG_NM>
# <BUILD_YEAR>2024</BUILD_YEAR>
# <HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>
# <CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>
# <NEW_RON_SECD>신규</NEW_RON_SECD>
# <CNTRCT_UPDT_RQEST_AT/>
# <BEFORE_GRNTY_AMOUNT/>
# <BEFORE_MT_RENT_CHRGE/>
# </row>
# <row>
# <ACC_YEAR>2024</ACC_YEAR>
# <SGG_CD>11545</SGG_CD>
# <SGG_NM>금천구</SGG_NM>
# <BJDONG_CD>10200</BJDONG_CD>
# <BJDONG_NM>독산동</BJDONG_NM>
# <LAND_GBN>1</LAND_GBN>
# <LAND_GBN_NM>대지</LAND_GBN_NM>
# <BOBN>0144</BOBN>
# <BUBN>0019</BUBN>
# <FLR_NO>9</FLR_NO>
# <CNTRCT_DE>20240325</CNTRCT_DE>
# <RENT_GBN>전세</RENT_GBN>
# <RENT_AREA>21.37</RENT_AREA>
# <RENT_GTN>23600</RENT_GTN>
# <RENT_FEE>0</RENT_FEE>
# <BLDG_NM>킹캐슬8차</BLDG_NM>
# <BUILD_YEAR>2024</BUILD_YEAR>
# <HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>
# <CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>
# <NEW_RON_SECD>신규</NEW_RON_SECD>
# <CNTRCT_UPDT_RQEST_AT/>
# <BEFORE_GRNTY_AMOUNT/>
# <BEFORE_MT_RENT_CHRGE/>
# </row>
# <row>
# <ACC_YEAR>2024</ACC_YEAR>
# <SGG_CD>11470</SGG_CD>
# <SGG_NM>양천구</SGG_NM>
# <BJDONG_CD>10100</BJDONG_CD>
# <BJDONG_NM>신정동</BJDONG_NM>
# <LAND_GBN>1</LAND_GBN>
# <LAND_GBN_NM>대지</LAND_GBN_NM>
# <BOBN>1182</BOBN>
# <BUBN>0015</BUBN>
# <FLR_NO>5</FLR_NO>
# <CNTRCT_DE>20240325</CNTRCT_DE>
# <RENT_GBN>전세</RENT_GBN>
# <RENT_AREA>23.31</RENT_AREA>
# <RENT_GTN>21200</RENT_GTN>
# <RENT_FEE>0</RENT_FEE>
# <BLDG_NM>보스코 빌딩</BLDG_NM>
# <BUILD_YEAR>2020</BUILD_YEAR>
# <HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>
# <CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>
# <NEW_RON_SECD>신규</NEW_RON_SECD>
# <CNTRCT_UPDT_RQEST_AT/>
# <BEFORE_GRNTY_AMOUNT/>
# <BEFORE_MT_RENT_CHRGE/>
# </row>
# <row>
# <ACC_YEAR>2024</ACC_YEAR>
# <SGG_CD>11230</SGG_CD>
# <SGG_NM>동대문구</SGG_NM>
# <BJDONG_CD>10400</BJDONG_CD>
# <BJDONG_NM>전농동</BJDONG_NM>
# <LAND_GBN>1</LAND_GBN>
# <LAND_GBN_NM>대지</LAND_GBN_NM>
# <BOBN>0620</BOBN>
# <BUBN>0071</BUBN>
# <FLR_NO>10</FLR_NO>
# <CNTRCT_DE>20240325</CNTRCT_DE>
# <RENT_GBN>월세</RENT_GBN>
# <RENT_AREA>43.44</RENT_AREA>
# <RENT_GTN>3000</RENT_GTN>
# <RENT_FEE>150</RENT_FEE>
# <BLDG_NM>청량리더블유디세븐스</BLDG_NM>
# <BUILD_YEAR>2023</BUILD_YEAR>
# <HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>
# <CNTRCT_PRD>24.04~25.04</CNTRCT_PRD>
# <NEW_RON_SECD>신규</NEW_RON_SECD>
# <CNTRCT_UPDT_RQEST_AT/>
# <BEFORE_GRNTY_AMOUNT/>
# <BEFORE_MT_RENT_CHRGE/>
# </row>
# </tbLnOpendataRentV>

# %%
#fromstring 메소드를 통해 XML 자료형을 처리할 수 있음
ET.fromstring(response.text)
# Out:
# <Element 'tbLnOpendataRentV' at 0x7c32746a9c60>

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<tbLnOpendataRentV>\n<list_total_count>5791017</list_total_count>\n<RESULT>\n<CODE>INFO-000</CODE>\n<MESSAGE>정상 처리되었습니다</MESSAGE>\n</RESULT>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11230</SGG_CD>\n<SGG_NM>동대문구</SGG_NM>\n<BJDONG_CD>10700</BJDONG_CD>\n<BJDONG_NM>청량리동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0235</BOBN>\n<BUBN>0006</BUBN>\n<FLR_NO>16</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>20.92</RENT_AREA>\n<RENT_GTN>1000</RENT_GTN>\n<RENT_FEE>100</RENT_FEE>\n<BLDG_NM>힐스테이트 청량리역</BLDG_NM>\n<BUILD_YEAR>2023</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.03~25.03</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11560</SGG_CD>\n<SGG_NM>영등포구</SGG_NM>\n<BJDONG_CD>10900</BJDONG_CD>\n<BJDONG_NM>영등포동8가</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0065</BOBN>\n<BUBN>0001</BUBN>\n<FLR_NO>6</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>17.58</RENT_AREA>\n<RENT_GTN>22000</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>엠캐슬150</BLDG_NM>\n<BUILD_YEAR>2024</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11545</SGG_CD>\n<SGG_NM>금천구</SGG_NM>\n<BJDONG_CD>10200</BJDONG_CD>\n<BJDONG_NM>독산동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0144</BOBN>\n<BUBN>0019</BUBN>\n<FLR_NO>9</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>21.37</RENT_AREA>\n<RENT_GTN>23600</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>킹캐슬8차</BLDG_NM>\n<BUILD_YEAR>2024</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11470</SGG_CD>\n<SGG_NM>양천구</SGG_NM>\n<BJDONG_CD>10100</BJDONG_CD>\n<BJDONG_NM>신정동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>1182</BOBN>\n<BUBN>0015</BUBN>\n<FLR_NO>5</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>전세</RENT_GBN>\n<RENT_AREA>23.31</RENT_AREA>\n<RENT_GTN>21200</RENT_GTN>\n<RENT_FEE>0</RENT_FEE>\n<BLDG_NM>보스코 빌딩</BLDG_NM>\n<BUILD_YEAR>2020</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~26.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n<row>\n<ACC_YEAR>2024</ACC_YEAR>\n<SGG_CD>11230</SGG_CD>\n<SGG_NM>동대문구</SGG_NM>\n<BJDONG_CD>10400</BJDONG_CD>\n<BJDONG_NM>전농동</BJDONG_NM>\n<LAND_GBN>1</LAND_GBN>\n<LAND_GBN_NM>대지</LAND_GBN_NM>\n<BOBN>0620</BOBN>\n<BUBN>0071</BUBN>\n<FLR_NO>10</FLR_NO>\n<CNTRCT_DE>20240325</CNTRCT_DE>\n<RENT_GBN>월세</RENT_GBN>\n<RENT_AREA>43.44</RENT_AREA>\n<RENT_GTN>3000</RENT_GTN>\n<RENT_FEE>150</RENT_FEE>\n<BLDG_NM>청량리더블유디세븐스</BLDG_NM>\n<BUILD_YEAR>2023</BUILD_YEAR>\n<HOUSE_GBN_NM>오피스텔</HOUSE_GBN_NM>\n<CNTRCT_PRD>24.04~25.04</CNTRCT_PRD>\n<NEW_RON_SECD>신규</NEW_RON_SECD>\n<CNTRCT_UPDT_RQEST_AT/>\n<BEFORE_GRNTY_AMOUNT/>\n<BEFORE_MT_RENT_CHRGE/>\n</row>\n</tbLnOpendataRentV>\n'

# %%
#강의 때 들은 방식으로X

root = ET.fromstring(response.text)
row_dict = {'ACC_YEAR':[],'SGG_CD':[],'SGG_NM':[],'BJDONG_CD':[],'BJDONG_NM':[],'LAND_GBN':[],
'LAND_GBN_NM':[],'BOBN':[],'BUBN':[],'FLR_NO':[],'CNTRCT_DE':[],'RENT_GBN':[],'RENT_AREA':[],'RENT_GTN':[],'RENT_FEE':[],'BLDG_NM':[],'BUILD_YEAR':[]
,'HOUSE_GBN_NM':[],'CNTRCT_PRD':[],'NEW_RON_SECD':[],'CNTRCT_UPDT_RQEST_AT':[],'BEFORE_GRNTY_AMOUNT':[],'BEFORE_MT_RENT_CHRGE':[]}
#data/item 계층 밑의 값을 list으로 가져와 iteration
for i in root.findall('./data/row'):
    # ROW로부터 텍스트를 가져와 딕셔너리에 저장
    for j in i:
        row_dict[j.tag].append(j.text)
df = pd.DataFrame(row_dict)
df.head()


#정규형 2형 만족X : kind_name에 두가지 종류
#dpr1 문자형
# Out:
# Empty DataFrame
# Columns: [ACC_YEAR, SGG_CD, SGG_NM, BJDONG_CD, BJDONG_NM, LAND_GBN, LAND_GBN_NM, BOBN, BUBN, FLR_NO, CNTRCT_DE, RENT_GBN, RENT_AREA, RENT_GTN, RENT_FEE, BLDG_NM, BUILD_YEAR, HOUSE_GBN_NM, CNTRCT_PRD, NEW_RON_SECD, CNTRCT_UPDT_RQEST_AT, BEFORE_GRNTY_AMOUNT, BEFORE_MT_RENT_CHRGE]
# Index: []
#
# [0 rows x 23 columns]

# %%
import pandas as pd

# XML을 DataFrame으로 변환
df = pd.read_xml(response.text)

# 필요한 컬럼 선택
columns_to_keep = ['ACC_YEAR', 'SGG_CD', 'SGG_NM', 'BJDONG_CD', 'BJDONG_NM', 'LAND_GBN', 'LAND_GBN_NM', 'BOBN', 'BUBN', 'FLR_NO', 'CNTRCT_DE', 'RENT_GBN', 'RENT_AREA', 'RENT_GTN', 'RENT_FEE', 'BLDG_NM', 'BUILD_YEAR', 'HOUSE_GBN_NM', 'CNTRCT_PRD', 'NEW_RON_SECD', 'CNTRCT_UPDT_RQEST_AT', 'BEFORE_GRNTY_AMOUNT', 'BEFORE_MT_RENT_CHRGE']
df = df[columns_to_keep]

# 결과 확인
usefull = ['ACC_YEAR', 'SGG_CD', 'SGG_NM', 'BJDONG_NM', 'FLR_NO', 'CNTRCT_DE', 'RENT_GBN', 'RENT_AREA', 'RENT_FEE', 'BLDG_NM','BUILD_YEAR', 'HOUSE_GBN_NM']
df[usefull].head(20)
# Out:
#     ACC_YEAR   SGG_CD SGG_NM BJDONG_NM  FLR_NO   CNTRCT_DE RENT_GBN  \
# 0        NaN      NaN   None      None     NaN         NaN     None
# 1        NaN      NaN   None      None     NaN         NaN     None
# 2     2024.0  11650.0    서초구       서초동     9.0  20240325.0       월세
# 3     2024.0  11500.0    강서구       마곡동     8.0  20240325.0       전세
# 4     2024.0  11560.0   영등포구       도림동     2.0  20240325.0       월세
# 5     2024.0  11230.0   동대문구      청량리동    16.0  20240325.0       월세
# 6     2024.0  11530.0    구로구      가리봉동     5.0  20240325.0       월세
# 7     2024.0  11545.0    금천구       독산동     9.0  20240325.0       전세
# 8     2024.0  11470.0    양천구       신정동     5.0  20240325.0       전세
# 9     2024.0  11545.0    금천구       가산동    12.0  20240325.0       전세
# 10    2024.0  11470.0    양천구       신정동     3.0  20240325.0       전세
# 11    2024.0  11170.0    용산구     원효로1가     4.0  20240325.0       월세
# 12    2024.0  11410.0   서대문구       대현동    10.0  20240325.0       월세
# 13    2024.0  11410.0   서대문구       대현동     8.0  20240325.0       월세
# 14    2024.0  11380.0    은평구       불광동     2.0  20240325.0       전세
# 15    2024.0  11230.0   동대문구       전농동    10.0  20240325.0       월세
# 16    2024.0  11545.0    금천구       독산동     7.0  20240325.0       전세
# 17    2024.0  11560.0   영등포구    영등포동8가     8.0  20240325.0       전세
# 18    2024.0  11560.0   영등포구     당산동3가     3.0  20240325.0       전세
# 19    2024.0  11710.0    송파구       문정동     3.0  20240325.0       월세
#
#     RENT_AREA  RENT_FEE         BLDG_NM  BUILD_YEAR HOUSE_GBN_NM
# 0         NaN       NaN            None         NaN         None
# 1         NaN       NaN            None         NaN         None
# 2       26.27      10.0    강남 효성 해링턴 타워      2013.0         오피스텔
# 3       24.57       0.0       힐스테이트에코동익      2017.0         오피스텔
# 4       30.87      50.0  도림동 하나 아파텔(2차)      2003.0         오피스텔
# 5       20.92     100.0      힐스테이트 청량리역      2023.0         오피스텔
# 6       42.89      10.0        (135-51)      2023.0         오피스텔
# 7       21.37       0.0           킹캐슬8차      2024.0         오피스텔
# 8       23.31       0.0          보스코 빌딩      2020.0         오피스텔
# 9       23.88       0.0         주건축물제1동      2023.0         오피스텔
# 10      19.99       0.0     목동중앙하이츠펠리시티      2021.0         오피스텔
# 11      19.46      45.0           용산파크뷰      2018.0         오피스텔
# 12      19.25      35.0    대현 3719 오피스텔      2023.0         오피스텔
# 13      14.97       9.0          신촌리브하임      2021.0         오피스텔
# 14      37.74       0.0         디앤제이하우징      2017.0         오피스텔
# 15      43.44     150.0      청량리더블유디세븐스      2023.0         오피스텔
# 16      33.69       0.0          블레어 가든      2023.0         오피스텔
# 17      20.43       0.0          엠캐슬150      2024.0         오피스텔
# 18      29.93       0.0            더하우스      2023.0         오피스텔
# 19      29.97     110.0        송파푸르지오시티      2013.0         오피스텔

# %%
root
# Out:
# <Element 'tbLnOpendataRentV' at 0x7c327471e7f0>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_name  74 non-null     object
#  1   item_code  74 non-null     object
#  2   kind_name  74 non-null     object
#  3   kind_code  74 non-null     object
#  4   rank       74 non-null     object
#  5   rank_code  74 non-null     object
#  6   unit       74 non-null     object
#  7   day1       74 non-null     object
#  8   dpr1       74 non-null     object
#  9   day2       74 non-null     object
#  10  dpr2       74 non-null     object
#  11  day3       74 non-null     object
#  12  dpr3       74 non-null     object
#  13  day4       74 non-null     object
#  14  dpr4       74 non-null     object
#  15  day5       74 non-null     object
#  16  dpr5       74 non-null     object
#  17  day6       74 non-null     object
#  18  dpr6       74 non-null     object
#  19  day7       74 non-null     object
#  20  dpr7       74 non-null     object
# dtypes: object(21)
# memory usage: 12.3+ KB

# %%
#깃허브 코드 복사
#리눅스 명령어
# !git clone 'https://github.com/bellepoque7/whereisplanb.git'
# Out:
# Cloning into 'whereisplanb'...
# remote: Enumerating objects: 944, done.
# remote: Counting objects: 100% (317/317), done.
# remote: Compressing objects: 100% (230/230), done.
# remote: Total 944 (delta 131), reused 252 (delta 78), pack-reused 627
# Receiving objects: 100% (944/944), 2.95 MiB | 14.94 MiB/s, done.
# Resolving deltas: 100% (176/176), done.
